# %%
import json
import string
import random
import nltk
nltk.download('omw-1.4')
import numpy as num
from nltk.stem import WordNetLemmatizer # It has the ability to lemmatize.
import tensorflow as tensorF # A multidimensional array of elements is represented by this symbol.
from tensorflow.keras import Sequential # Sequential groups a linear stack of layers into a tf.keras.Model
from tensorflow.keras.layers import Dense, Dropout

nltk.download("punkt")# required package for tokenization
nltk.download("wordnet")# word database
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
ourData = {"ourIntents": [

             {"tag": "pemesanan",
              "patterns": ["Bagaimana cara memesan produk??"],
              "responses": ["Anda dapat memesan produk dengan mengklik tombol \"Beli Sekarang\" di halaman produk. Setelah itu, ikuti langkah-langkah checkout untuk menyelesaikan pembelian."]
             },
              {"tag": "greeting",
              "patterns": [ "Hi", "Hello", "Hey"],
              "responses": ["Hi there", "Hello", "Hi :)"],
             },
              {"tag": "goodbye",
              "patterns": [ "bye", "later"],
              "responses": ["Bye", "take care"]
             },
             {"tag": "metode pembayaran",
              "patterns": ["Apa metode pembayaran yang diterima?"],
              "responses": ["Kami menerima pembayaran melalui transfer bank, kartu kredit, dan layanan pembayaran online seperti PayPal. Pilih opsi pembayaran yang paling nyaman untuk Anda saat checkout."]
             },
             {"tag": "pengiriman",
              "patterns":["Berapa lama waktu pengiriman ke lokasi saya?"],
              "responses":["Waktu pengiriman dapat bervariasi tergantung lokasi pengiriman. Saat checkout, sistem akan memberikan perkiraan waktu pengiriman berdasarkan alamat yang Anda berikan."]
             },
             {"tag": "stock",
              "patterns": [ "Apakah produk ini masih tersedia?"],
              "responses": ["Untuk mengecek ketersediaan stok, Anda dapat melihat status stok di halaman produk. Jika stok habis, biasanya akan tertera di situ."]
             },
              {"tag": "retur",
              "patterns": [ "Bagaimana prosedur untuk retur produk?"],
              "responses": ["Jika Anda ingin melakukan retur, silakan hubungi layanan pelanggan kami dengan menyertakan nomor pesanan dan alasan retur. Kami akan memberikan petunjuk lebih lanjut."]
             },
              {"tag": "produk",
              "patterns": [ "Dapatkah Anda memberikan informasi lebih lanjut tentang spesifikasi produk ini?"],
              "responses": ["Tentu! Silakan kunjungi halaman produk untuk melihat informasi detail, atau hubungi tim dukungan kami jika Anda memerlukan bantuan lebih lanjut."]
             },
             {"tag": "harga",
              "patterns": [ "Apakah harga produk sudah termasuk pajak dan biaya lainnya?"],
              "responses": ["Harga produk yang tercantum belum termasuk pajak dan biaya pengiriman. Pajak dan biaya tambahan akan dihitung saat proses checkout."]
             }

]}

# %%
lm = WordNetLemmatizer() #for getting words
# lists
ourClasses = []
newWords = []
documentX = []
documentY = []
# Each intent is tokenized into words and the patterns and their associated tags are added to their respective lists.
for intent in ourData["ourIntents"]:
    for pattern in intent["patterns"]:
        ournewTkns = nltk.word_tokenize(pattern)# tokenize the patterns
        newWords.extend(ournewTkns)# extends the tokens
        documentX.append(pattern)
        documentY.append(intent["tag"])


    if intent["tag"] not in ourClasses:# add unexisting tags to their respective classes
        ourClasses.append(intent["tag"])

newWords = [lm.lemmatize(word.lower()) for word in newWords if word not in string.punctuation] # set words to lowercase if not in punctuation
newWords = sorted(set(newWords))# sorting words
ourClasses = sorted(set(ourClasses))# sorting classes

# %%
trainingData = [] # training list array
outEmpty = [0] * len(ourClasses)
# bow model
for idx, doc in enumerate(documentX):
    bagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in newWords:
        bagOfwords.append(1) if word in text else bagOfwords.append(0)

    outputRow = list(outEmpty)
    outputRow[ourClasses.index(documentY[idx])] = 1
    trainingData.append([bagOfwords, outputRow])

random.shuffle(trainingData)
trainingData = num.array(trainingData, dtype=object)# coverting our data into an array afterv shuffling

x = num.array(list(trainingData[:, 0]))# first trainig phase
y = num.array(list(trainingData[:, 1]))# second training phase

# %%
iShape = (len(x[0]),)
oShape = len(y[0])
# parameter definition
ourNewModel = Sequential()
# In the case of a simple stack of layers, a Sequential model is appropriate

# Dense function adds an output layer
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu"))
# The activation function in a neural network is in charge of converting the node's summed weighted input into activation of the node or output for the input in question
ourNewModel.add(Dropout(0.5))
# Dropout is used to enhance visual perception of input neurons
ourNewModel.add(Dense(64, activation="relu"))
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation = "softmax"))
# below is a callable that returns the value to be used with no arguments
md = tensorF.keras.optimizers.Adam(learning_rate=0.005)
# Below line improves the numerical stability and pushes the computation of the probability distribution into the categorical crossentropy loss function.
ourNewModel.compile(loss='categorical_crossentropy',
              optimizer=md,
              metrics=["accuracy"])
# Output the model in summary
print(ourNewModel.summary())
# Whilst training your Nural Network, you have the option of making the output verbose or simple.
ourNewModel.fit(x, y, epochs=200, verbose=1)
# By epochs, we mean the number of times you repeat a training set.
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               5632
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 9)                 585
#
# =================================================================
# Total params: 14473 (56.54 KB)
# Trainable params: 14473 (56.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 1s 982ms/step - loss: 2.2077 - accuracy: 0.0833
# Epoch 2/200
# 1/1 [==============================] - 0s 16ms/step - loss: 2.2159 - accuracy: 0.1667
# Epoch 3/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.9788 - accuracy: 0.3333
# Epoch 4/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9600 - accuracy: 0.5000
# Epoch 5/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.8312 - accuracy: 0.5000
# Epoch 6/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7612 - accuracy: 0.8333
# Epoch 7/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6730 - accuracy: 0.5833
# Epoch 8/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4922 - accuracy: 0.7500
# Epoch 9/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.5333 - accuracy: 0.8333
# Epoch 10/200
# 1/1 [==============================] - 0s 30ms/step - loss: 1.5435 - accuracy: 0.5000
# Epoch 11/200
# 1/1 [==============================] - 0s 36ms/step - loss: 1.4516 - accuracy: 0.8333
# Epoch 12/200
# 1/1 [==============================] - 0s 43ms/step - loss: 1.3180 - accuracy: 0.8333
# Epoch 13/200
# 1/1 [==============================] - 0s 40ms/step - loss: 1.1430 - accuracy: 0.8333
# Epoch 14/200
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0252 - accuracy: 1.0000
# Epoch 15/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8961 - accuracy: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.9563 - accuracy: 0.9167
# Epoch 17/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.9685 - accuracy: 0.8333
# Epoch 18/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6695 - accuracy: 0.9167
# Epoch 19/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5448 - accuracy: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5677 - accuracy: 0.9167
# Epoch 21/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4240 - accuracy: 1.0000
# Epoch 22/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5443 - accuracy: 0.9167
# Epoch 23/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3713 - accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3328 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.3266 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3372 - accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1782 - accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3464 - accuracy: 0.9167
# Epoch 29/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2044 - accuracy: 0.9167
# Epoch 30/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1203 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0871 - accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2377 - accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2046 - accuracy: 0.9167
# Epoch 34/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0520 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0506 - accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1008 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0586 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1088 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2544 - accuracy: 0.9167
# Epoch 40/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0526 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0706 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0495 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0594 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0458 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2471 - accuracy: 0.9167
# Epoch 48/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0670 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0579 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0977 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0426 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0304 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0347 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0503 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 13ms/step - loss: 8.9540e-04 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0312 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0599 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0658 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 13ms/step - loss: 3.7644e-04 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0473 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.3708e-04 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0508 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0616 - accuracy: 0.9167
# Epoch 131/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.2909e-04 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 13ms/step - loss: 4.8879e-04 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 13ms/step - loss: 9.5918e-04 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.2508e-04 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.8003e-04 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 13ms/step - loss: 5.6541e-04 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0564 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 11ms/step - loss: 9.3472e-04 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 11ms/step - loss: 6.7483e-04 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 15ms/step - loss: 6.5809e-04 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 14ms/step - loss: 2.4082e-04 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 13ms/step - loss: 4.6872e-04 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1288e-04 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 13ms/step - loss: 4.1661e-04 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.8610e-04 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 11ms/step - loss: 9.4631e-04 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 22ms/step - loss: 7.3727e-04 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0036 - accuracy: 1.0000

# %%
def ourText(text):
  newtkns = nltk.word_tokenize(text)
  newtkns = [lm.lemmatize(word) for word in newtkns]
  return newtkns

def wordBag(text, vocab):
  newtkns = ourText(text)
  bagOwords = [0] * len(vocab)
  for w in newtkns:
    for idx, word in enumerate(vocab):
      if word == w:
        bagOwords[idx] = 1
  return num.array(bagOwords)

def Pclass(text, vocab, labels):
  bagOwords = wordBag(text, vocab)
  ourResult = ourNewModel.predict(num.array([bagOwords]))[0]
  newThresh = 0.2
  yp = [[idx, res] for idx, res in enumerate(ourResult) if res > newThresh]

  yp.sort(key=lambda x: x[1], reverse=True)
  newList = []
  for r in yp:
    newList.append(labels[r[0]])
  return newList

def getRes(firstlist, fJson):
  tag = firstlist[0]
  listOfIntents = fJson["ourIntents"]
  for i in listOfIntents:
    if i["tag"] == tag:
      ourResult = random.choice(i["responses"])
      break
  return ourResult

# %%
while True:
    newMessage = input("")
    intents = Pclass(newMessage, newWords, ourClasses)
    ourResult = getRes(intents, ourData)
    print(ourResult)
# Out:
# stock
# 1/1 [==============================] - 0s 145ms/step
# Hi :)
# pengiriman
# 1/1 [==============================] - 0s 24ms/step
# Hello
# metode pembayaran?
# 1/1 [==============================] - 0s 20ms/step
# Kami menerima pembayaran melalui transfer bank, kartu kredit, dan layanan pembayaran online seperti PayPal. Pilih opsi pembayaran yang paling nyaman untuk Anda saat checkout.
# pengirimannya gimana?
# 1/1 [==============================] - 0s 33ms/step
# Hello
# retur produk
# 1/1 [==============================] - 0s 31ms/step
# Jika Anda ingin melakukan retur, silakan hubungi layanan pelanggan kami dengan menyertakan nomor pesanan dan alasan retur. Kami akan memberikan petunjuk lebih lanjut.
